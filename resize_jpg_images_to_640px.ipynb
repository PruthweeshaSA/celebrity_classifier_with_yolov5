# %%
import os
from PIL import Image

def resize_images(directory, max_size=640):
    """
    Resize all .jpg images in the directory (recursively),
    maintaining aspect ratio and capping the longest side at max_size.
    """
    for root, _, files in os.walk(directory):
        for filename in files:
            if not filename.lower().endswith('.jpg'):
                continue

            path = os.path.join(root, filename)

            try:
                with Image.open(path) as img:
                    w, h = img.size

                    # Check if resizing is needed
                    # if max(w, h) <= max_size:
                    #     continue  # Already within size limit

                    # Compute new size
                    if w >= h:
                        new_w = max_size
                        new_h = int(h * (max_size / w))
                    else:
                        new_h = max_size
                        new_w = int(w * (max_size / h))

                    resized = img.resize((new_w, new_h), Image.LANCZOS)
                    resized.save(path, format='JPEG', quality=95)
                    print(f"Resized: {filename} → {new_w}x{new_h}")

            except Exception as e:
                print(f"Error processing {filename}: {e}")

# %%
path_to_resize = r'C:\Documents\CelebrityClassifier\CelebrityFacesDataset_Curated\__No Face'

resize_images(path_to_resize)
# Out:
# Resized: noface (1).jpg → 640x640
# Resized: noface (10).jpg → 640x640
# Resized: noface (100).jpg → 640x640
# Resized: noface (101).jpg → 640x640
# Resized: noface (102).jpg → 640x640
# Resized: noface (103).jpg → 640x463
# Resized: noface (104).jpg → 454x640
# Resized: noface (105).jpg → 640x640
# Resized: noface (106).jpg → 640x640
# Resized: noface (107).jpg → 640x640
# Resized: noface (108).jpg → 640x640
# Resized: noface (109).jpg → 640x640
# Resized: noface (11).jpg → 640x640
# Resized: noface (110).jpg → 640x640
# Resized: noface (111).jpg → 640x358
# Resized: noface (112).jpg → 640x640
# Resized: noface (113).jpg → 640x640
# Resized: noface (114).jpg → 640x336
# Resized: noface (115).jpg → 640x640
# Resized: noface (116).jpg → 640x640
# Resized: noface (117).jpg → 640x640
# Resized: noface (118).jpg → 640x640
# Resized: noface (119).jpg → 640x640
# Resized: noface (12).jpg → 640x640
# Resized: noface (120).jpg → 640x640
# Resized: noface (121).jpg → 640x640
# Resized: noface (122).jpg → 640x640
# Resized: noface (123).jpg → 640x640
# Resized: noface (124).jpg → 640x640
# Resized: noface (125).jpg → 640x640
# Resized: noface (126).jpg → 401x640
# Resized: noface (127).jpg → 640x425
# Resized: noface (128).jpg → 640x402
# Resized: noface (129).jpg → 640x640
# Resized: noface (13).jpg → 640x640
# Resized: noface (130).jpg → 640x528
# Resized: noface (131).jpg → 640x640
# Resized: noface (132).jpg → 640x640
# Resized: noface (133).jpg → 640x640
# Resized: noface (134).jpg → 640x640
# Resized: noface (135).jpg → 640x640
# Resized: noface (136).jpg → 640x640
# Resized: noface (137).jpg → 640x640
# Resized: noface (138).jpg → 640x640
# Resized: noface (139).jpg → 640x640
# Resized: noface (14).jpg → 640x640
# Resized: noface (140).jpg → 640x640
# Resized: noface (141).jpg → 640x398
# Resized: noface (142).jpg → 640x425
# Resized: noface (143).jpg → 640x393
# Resized: noface (144).jpg → 640x479
# Resized: noface (145).jpg → 640x479
# Resized: noface (146).jpg → 640x640
# Resized: noface (147).jpg → 640x398
# Resized: noface (148).jpg → 640x640
# Resized: noface (149).jpg → 640x640
# Resized: noface (15).jpg → 640x640
# Resized: noface (150).jpg → 640x640
# Resized: noface (151).jpg → 640x640
# Resized: noface (152).jpg → 640x640
# Resized: noface (153).jpg → 640x479
# Resized: noface (154).jpg → 640x640
# Resized: noface (155).jpg → 640x640
# Resized: noface (156).jpg → 640x640
# Resized: noface (157).jpg → 640x640
# Resized: noface (158).jpg → 640x640
# Resized: noface (159).jpg → 640x640
# Resized: noface (16).jpg → 640x640
# Resized: noface (160).jpg → 640x640
# Resized: noface (161).jpg → 640x640
# Resized: noface (162).jpg → 640x640
# Resized: noface (163).jpg → 640x640
# Resized: noface (164).jpg → 640x640
# Resized: noface (165).jpg → 640x640
# Resized: noface (166).jpg → 640x640
# Resized: noface (167).jpg → 640x640
# Resized: noface (168).jpg → 640x425
# Resized: noface (169).jpg → 640x425
# Resized: noface (17).jpg → 640x640
# Resized: noface (170).jpg → 640x448
# Resized: noface (171).jpg → 640x640
# Resized: noface (172).jpg → 640x640
# Resized: noface (173).jpg → 640x640
# Resized: noface (174).jpg → 640x640
# Resized: noface (175).jpg → 640x640
# Resized: noface (176).jpg → 640x640
# Resized: noface (177).jpg → 640x640
# Resized: noface (178).jpg → 640x640
# Resized: noface (179).jpg → 640x481
# Resized: noface (18).jpg → 640x640
# Resized: noface (180).jpg → 640x640
# Resized: noface (181).jpg → 640x640
# Resized: noface (182).jpg → 640x640
# Resized: noface (183).jpg → 640x640
# Resized: noface (184).jpg → 640x640
# Resized: noface (185).jpg → 640x640
# Resized: noface (186).jpg → 640x640
# Resized: noface (187).jpg → 640x640
# Resized: noface (188).jpg → 640x640
# Resized: noface (189).jpg → 640x640
# Resized: noface (19).jpg → 640x640
# Resized: noface (190).jpg → 640x640
# Resized: noface (191).jpg → 640x640
# Resized: noface (192).jpg → 640x640
# Resized: noface (193).jpg → 479x640
# Resized: noface (194).jpg → 640x640
# Resized: noface (195).jpg → 640x640
# Resized: noface (196).jpg → 640x640
# Resized: noface (197).jpg → 640x479
# Resized: noface (198).jpg → 481x640
# Resized: noface (199).jpg → 640x640
# Resized: noface (2).jpg → 640x640
# Resized: noface (20).jpg → 640x640
# Resized: noface (200).jpg → 640x640
# Resized: noface (201).jpg → 640x640
# Resized: noface (202).jpg → 640x640
# Resized: noface (203).jpg → 640x640
# Resized: noface (204).jpg → 640x640
# Resized: noface (205).jpg → 640x426
# Resized: noface (206).jpg → 640x640
# Resized: noface (207).jpg → 640x640
# Resized: noface (208).jpg → 640x640
# Resized: noface (209).jpg → 640x640
# Resized: noface (21).jpg → 640x640
# Resized: noface (210).jpg → 640x481
# Resized: noface (211).jpg → 640x557
# Resized: noface (212).jpg → 640x640
# Resized: noface (213).jpg → 640x640
# Resized: noface (214).jpg → 640x640
# Resized: noface (215).jpg → 640x640
# Resized: noface (216).jpg → 640x640
# Resized: noface (217).jpg → 640x425
# Resized: noface (218).jpg → 640x640
# Resized: noface (219).jpg → 640x640
# Resized: noface (22).jpg → 640x640
# Resized: noface (220).jpg → 640x640
# Resized: noface (221).jpg → 640x640
# Resized: noface (222).jpg → 640x333
# Resized: noface (223).jpg → 640x640
# Resized: noface (224).jpg → 640x402
# Resized: noface (225).jpg → 640x640
# Resized: noface (226).jpg → 640x640
# Resized: noface (227).jpg → 640x640
# Resized: noface (228).jpg → 640x640
# Resized: noface (229).jpg → 640x640
# Resized: noface (23).jpg → 640x640
# Resized: noface (230).jpg → 640x640
# Resized: noface (231).jpg → 640x640
# Resized: noface (232).jpg → 640x640
# Resized: noface (233).jpg → 640x640
# Resized: noface (234).jpg → 640x640
# Resized: noface (235).jpg → 640x640
# Resized: noface (236).jpg → 640x640
# Resized: noface (237).jpg → 640x640
# Resized: noface (238).jpg → 640x640
# Resized: noface (239).jpg → 640x555
# Resized: noface (24).jpg → 640x640
# Resized: noface (240).jpg → 640x640
# Resized: noface (241).jpg → 640x480
# Resized: noface (242).jpg → 640x510
# Resized: noface (243).jpg → 640x640
# Resized: noface (244).jpg → 640x479
# Resized: noface (245).jpg → 640x640
# Resized: noface (246).jpg → 640x640
# Resized: noface (247).jpg → 640x640
# Resized: noface (248).jpg → 640x425
# Resized: noface (249).jpg → 640x640
# Resized: noface (25).jpg → 640x640
# Resized: noface (250).jpg → 640x358
# Resized: noface (251).jpg → 640x640
# Resized: noface (252).jpg → 640x640
# Resized: noface (253).jpg → 640x640
# Resized: noface (254).jpg → 640x640
# Resized: noface (255).jpg → 640x640
# Resized: noface (256).jpg → 640x388
# Resized: noface (257).jpg → 640x367
# Resized: noface (258).jpg → 640x640
# Resized: noface (259).jpg → 640x479
# Resized: noface (26).jpg → 640x640
# Resized: noface (260).jpg → 640x427
# Resized: noface (261).jpg → 640x479
# Resized: noface (262).jpg → 640x477
# Resized: noface (263).jpg → 640x424
# Resized: noface (264).jpg → 640x614
# Resized: noface (265).jpg → 640x427
# Resized: noface (266).jpg → 615x640
# Resized: noface (267).jpg → 640x640
# Resized: noface (268).jpg → 640x634
# Resized: noface (269).jpg → 638x640
# Resized: noface (27).jpg → 640x640
# Resized: noface (270).jpg → 640x640
# Resized: noface (271).jpg → 640x360
# Resized: noface (272).jpg → 640x640
# Resized: noface (273).jpg → 640x640
# Resized: noface (274).jpg → 640x640
# Resized: noface (275).jpg → 640x640
# Resized: noface (276).jpg → 640x640
# Resized: noface (277).jpg → 640x426
# Resized: noface (278).jpg → 640x454
# Resized: noface (279).jpg → 640x484
# Resized: noface (28).jpg → 640x640
# Resized: noface (280).jpg → 640x640
# Resized: noface (281).jpg → 640x640
# Resized: noface (282).jpg → 640x425
# Resized: noface (283).jpg → 640x640
# Resized: noface (284).jpg → 640x480
# Resized: noface (285).jpg → 640x427
# Resized: noface (286).jpg → 640x636
# Resized: noface (287).jpg → 640x640
# Resized: noface (288).JPG → 640x636
# Resized: noface (289).jpg → 640x640
# Resized: noface (29).jpg → 640x640
# Resized: noface (290).jpg → 640x640
# Resized: noface (291).jpg → 640x472
# Resized: noface (292).jpg → 640x640
# Resized: noface (293).jpg → 640x591
# Resized: noface (294).jpg → 640x640
# Resized: noface (295).jpg → 640x372
# Resized: noface (296).jpg → 640x640
# Resized: noface (297).jpg → 640x640
# Resized: noface (298).jpg → 640x640
# Resized: noface (299).jpg → 640x640
# Resized: noface (3).jpg → 640x640
# Resized: noface (30).jpg → 640x640
# Resized: noface (300).jpg → 640x478
# Resized: noface (301).jpg → 640x464
# Resized: noface (302).jpg → 640x640
# Resized: noface (303).jpg → 640x360
# Resized: noface (304).jpg → 640x426
# Resized: noface (305).jpg → 640x640
# Resized: noface (306).jpg → 640x640
# Resized: noface (307).jpg → 640x640
# Resized: noface (308).jpg → 640x640
# Resized: noface (309).jpg → 640x640
# Resized: noface (31).jpg → 640x640
# Resized: noface (310).jpg → 640x640
# Resized: noface (311).jpg → 640x640
# Resized: noface (312).jpg → 640x640
# Resized: noface (313).jpg → 640x640
# Resized: noface (314).jpg → 640x640
# Resized: noface (315).jpg → 640x640
# Resized: noface (316).jpg → 640x635
# Resized: noface (317).jpg → 640x640
# Resized: noface (318).jpg → 640x640
# Resized: noface (319).jpg → 640x423
# Resized: noface (32).jpg → 640x640
# Resized: noface (320).jpg → 640x640
# Resized: noface (321).jpg → 640x640
# Resized: noface (322).jpg → 640x640
# Resized: noface (323).jpg → 640x640
# Resized: noface (324).jpg → 640x640
# Resized: noface (325).jpg → 640x640
# Resized: noface (326).jpg → 640x640
# Resized: noface (327).jpg → 640x640
# Resized: noface (328).jpg → 640x640
# Resized: noface (329).jpg → 640x640
# Resized: noface (33).jpg → 640x640
# Resized: noface (330).jpg → 640x640
# Resized: noface (331).jpg → 640x640
# Resized: noface (332).jpg → 640x640
# Resized: noface (333).jpg → 640x640
# Resized: noface (334).jpg → 640x640
# Resized: noface (335).jpg → 640x640
# Resized: noface (336).jpg → 640x640
# Resized: noface (337).jpg → 640x640
# Resized: noface (338).jpg → 640x640
# Resized: noface (339).jpg → 640x640
# Resized: noface (34).jpg → 640x640
# Resized: noface (340).jpg → 640x640
# Resized: noface (341).jpg → 640x640
# Resized: noface (342).jpg → 640x640
# Resized: noface (343).jpg → 640x640
# Resized: noface (344).jpg → 640x640
# Resized: noface (345).jpg → 640x640
# Resized: noface (346).jpg → 640x640
# Resized: noface (347).jpg → 640x640
# Resized: noface (348).jpg → 640x640
# Resized: noface (349).jpg → 640x640
# Resized: noface (35).jpg → 640x640
# Resized: noface (350).jpg → 640x640
# Resized: noface (351).jpg → 640x640
# Resized: noface (352).jpg → 640x640
# Resized: noface (353).jpg → 640x640
# Resized: noface (354).jpg → 640x640
# Resized: noface (355).jpg → 640x640
# Resized: noface (356).jpg → 640x640
# Resized: noface (357).jpg → 640x640
# Resized: noface (358).jpg → 640x640
# Resized: noface (359).jpg → 640x640
# Resized: noface (36).jpg → 640x640
# Resized: noface (360).jpg → 640x640
# Resized: noface (361).jpg → 640x640
# Resized: noface (362).jpg → 640x640
# Resized: noface (363).jpg → 640x640
# Resized: noface (364).jpg → 640x640
# Resized: noface (365).jpg → 640x640
# Resized: noface (366).jpg → 640x640
# Resized: noface (367).jpg → 640x640
# Resized: noface (368).jpg → 640x640
# Resized: noface (369).jpg → 640x640
# Resized: noface (37).jpg → 640x640
# Resized: noface (370).jpg → 640x640
# Resized: noface (371).jpg → 640x640
# Resized: noface (372).jpg → 640x640
# Resized: noface (373).jpg → 640x640
# Resized: noface (374).jpg → 640x640
# Resized: noface (375).jpg → 640x640
# Resized: noface (376).jpg → 640x391
# Resized: noface (377).jpg → 640x640
# Resized: noface (378).jpg → 640x640
# Resized: noface (379).jpg → 640x437
# Resized: noface (38).jpg → 640x640
# Resized: noface (380).jpg → 640x640
# Resized: noface (381).jpg → 640x640
# Resized: noface (382).jpg → 640x640
# Resized: noface (383).jpg → 640x640
# Resized: noface (384).jpg → 640x640
# Resized: noface (385).jpg → 640x640
# Resized: noface (386).jpg → 640x640
# Resized: noface (387).jpg → 640x640
# Resized: noface (388).jpg → 640x640
# Resized: noface (389).jpg → 640x423
# Resized: noface (39).jpg → 640x640
# Resized: noface (390).jpg → 640x640
# Resized: noface (391).jpg → 640x640
# Resized: noface (392).jpg → 640x640
# Resized: noface (393).jpg → 640x640
# Resized: noface (394).jpg → 640x640
# Resized: noface (395).jpg → 640x640
# Resized: noface (396).jpg → 640x640
# Resized: noface (397).jpg → 640x640
# Resized: noface (398).jpg → 640x640
# Resized: noface (399).jpg → 640x640
# Resized: noface (4).jpg → 640x640
# Resized: noface (40).jpg → 640x640
# Resized: noface (400).jpg → 640x640
# Resized: noface (401).jpg → 640x640
# Resized: noface (402).jpg → 640x640
# Resized: noface (403).jpg → 640x640
# Resized: noface (404).jpg → 640x640
# Resized: noface (405).jpg → 640x640
# Resized: noface (406).jpg → 640x640
# Resized: noface (407).jpg → 640x640
# Resized: noface (408).jpg → 640x640
# Resized: noface (409).jpg → 640x640
# Resized: noface (41).jpg → 640x640
# Resized: noface (410).jpg → 640x640
# Resized: noface (411).jpg → 640x640
# Resized: noface (412).jpg → 640x640
# Resized: noface (413).jpg → 640x640
# Resized: noface (414).jpg → 640x640
# Resized: noface (415).jpg → 640x640
# Resized: noface (416).jpg → 640x640
# Resized: noface (417).jpg → 640x640
# Resized: noface (418).jpg → 640x640
# Resized: noface (419).jpg → 640x640
# Resized: noface (42).jpg → 640x640
# Resized: noface (420).jpg → 640x640
# Resized: noface (421).jpg → 640x640
# Resized: noface (422).jpg → 640x640
# Resized: noface (423).jpg → 640x640
# Resized: noface (424).jpg → 640x640
# Resized: noface (425).jpg → 640x640
# Resized: noface (426).jpg → 640x640
# Resized: noface (427).jpg → 640x640
# Resized: noface (428).jpg → 640x426
# Resized: noface (429).jpg → 640x640
# Resized: noface (43).jpg → 640x640
# Resized: noface (430).jpg → 640x640
# Resized: noface (431).jpg → 640x640
# Resized: noface (432).jpg → 640x640
# Resized: noface (433).jpg → 640x640
# Resized: noface (434).jpg → 640x640
# Resized: noface (435).jpg → 640x640
# Resized: noface (436).jpg → 640x640
# Resized: noface (437).jpg → 640x426
# Resized: noface (438).jpg → 640x640
# Resized: noface (439).jpg → 640x454
# Resized: noface (44).jpg → 640x640
# Resized: noface (440).jpg → 640x640
# Resized: noface (441).jpg → 640x640
# Resized: noface (442).jpg → 640x640
# Resized: noface (443).jpg → 640x640
# Resized: noface (444).jpg → 640x640
# Resized: noface (445).jpg → 640x426
# Resized: noface (446).jpg → 640x640
# Resized: noface (447).jpg → 640x640
# Resized: noface (448).jpg → 640x640
# Resized: noface (449).jpg → 640x640
# Resized: noface (45).jpg → 640x640
# Resized: noface (450).jpg → 640x640
# Resized: noface (451).jpg → 640x640
# Resized: noface (452).jpg → 640x640
# Resized: noface (453).jpg → 640x640
# Resized: noface (454).jpg → 640x640
# Resized: noface (455).jpg → 640x640
# Resized: noface (456).jpg → 640x640
# Resized: noface (457).jpg → 640x640
# Resized: noface (458).jpg → 640x640
# Resized: noface (459).jpg → 640x640
# Resized: noface (46).jpg → 640x640
# Resized: noface (460).jpg → 640x640
# Resized: noface (461).jpg → 640x640
# Resized: noface (462).jpg → 640x640
# Resized: noface (463).jpg → 640x480
# Resized: noface (464).jpg → 640x640
# Resized: noface (465).jpg → 640x640
# Resized: noface (466).jpg → 640x640
# Resized: noface (467).jpg → 640x480
# Resized: noface (468).jpg → 640x480
# Resized: noface (469).jpg → 640x640
# Resized: noface (47).jpg → 640x429
# Resized: noface (470).jpg → 640x640
# Resized: noface (471).jpg → 640x480
# Resized: noface (472).jpg → 640x640
# Resized: noface (473).jpg → 640x640
# Resized: noface (474).jpg → 640x640
# Resized: noface (475).jpg → 640x640
# Resized: noface (476).jpg → 640x480
# Resized: noface (477).jpg → 640x640
# Resized: noface (478).jpg → 640x419
# Resized: noface (479).jpg → 640x640
# Resized: noface (48).jpg → 640x533
# Resized: noface (480).jpg → 640x640
# Resized: noface (481).jpg → 640x640
# Resized: noface (482).jpg → 640x640
# Resized: noface (483).jpg → 480x640
# Resized: noface (484).jpg → 640x640
# Resized: noface (485).jpg → 640x640
# Resized: noface (486).jpg → 640x640
# Resized: noface (487).jpg → 640x480
# Resized: noface (488).jpg → 640x480
# Resized: noface (489).jpg → 640x480
# Resized: noface (49).jpg → 640x398
# Resized: noface (490).jpg → 640x640
# Resized: noface (491).jpg → 640x480
# Resized: noface (492).jpg → 640x480
# Resized: noface (493).jpg → 640x480
# Resized: noface (494).jpg → 640x480
# Resized: noface (495).jpg → 640x640
# Resized: noface (496).jpg → 640x640
# Resized: noface (497).jpg → 640x640
# Resized: noface (498).jpg → 640x480
# Resized: noface (499).jpg → 640x640
# Resized: noface (5).jpg → 640x640
# Resized: noface (50).jpg → 506x640
# Resized: noface (500).jpg → 640x480
# Resized: noface (501).jpg → 640x640
# Resized: noface (502).jpg → 640x480
# Resized: noface (503).jpg → 640x480
# Resized: noface (504).jpg → 640x480
# Resized: noface (505).jpg → 640x480
# Resized: noface (506).jpg → 640x480
# Resized: noface (507).jpg → 640x480
# Resized: noface (508).jpg → 640x480
# Resized: noface (509).jpg → 640x640
# Resized: noface (51).jpg → 640x359
# Resized: noface (510).jpg → 640x480
# Resized: noface (511).jpg → 640x480
# Resized: noface (512).jpg → 640x480
# Resized: noface (513).jpg → 640x640
# Resized: noface (514).jpg → 640x480
# Resized: noface (515).jpg → 640x480
# Resized: noface (516).jpg → 640x480
# Resized: noface (517).jpg → 640x480
# Resized: noface (518).jpg → 640x480
# Resized: noface (519).jpg → 640x480
# Resized: noface (52).jpg → 640x398
# Resized: noface (520).jpg → 640x480
# Resized: noface (521).jpg → 640x480
# Resized: noface (522).jpg → 640x480
# Resized: noface (523).jpg → 640x480
# Resized: noface (524).jpg → 640x480
# Resized: noface (525).jpg → 640x480
# Resized: noface (526).jpg → 640x480
# Resized: noface (527).jpg → 640x480
# Resized: noface (528).jpg → 640x480
# Resized: noface (529).jpg → 640x480
# Resized: noface (53).jpg → 640x477
# Resized: noface (530).jpg → 640x480
# Resized: noface (531).jpg → 640x480
# Resized: noface (532).jpg → 640x480
# Resized: noface (533).jpg → 640x480
# Resized: noface (534).jpg → 640x480
# Resized: noface (535).jpg → 640x480
# Resized: noface (536).jpg → 640x480
# Resized: noface (537).jpg → 640x480
# Resized: noface (538).jpg → 640x640
# Resized: noface (539).jpg → 640x480
# Resized: noface (54).jpg → 640x640
# Resized: noface (540).jpg → 640x480
# Resized: noface (541).jpg → 640x480
# Resized: noface (542).jpg → 640x480
# Resized: noface (543).jpg → 640x480
# Resized: noface (544).jpg → 640x480
# Resized: noface (545).jpg → 640x480
# Resized: noface (546).jpg → 640x480
# Resized: noface (547).jpg → 640x480
# Resized: noface (548).jpg → 640x480
# Resized: noface (549).jpg → 640x480
# Resized: noface (55).jpg → 640x640
# Resized: noface (550).jpg → 640x480
# Resized: noface (551).jpg → 640x480
# Resized: noface (552).jpg → 640x480
# Resized: noface (553).jpg → 640x480
# Resized: noface (554).jpg → 640x480
# Resized: noface (555).jpg → 640x480
# Resized: noface (556).jpg → 640x480
# Resized: noface (557).jpg → 640x480
# Resized: noface (558).jpg → 640x480
# Resized: noface (559).jpg → 640x480
# Resized: noface (56).jpg → 640x398
# Resized: noface (560).jpg → 640x480
# Resized: noface (561).jpg → 640x480
# Resized: noface (562).jpg → 640x480
# Resized: noface (563).jpg → 640x480
# Resized: noface (564).jpg → 640x480
# Resized: noface (565).jpg → 640x480
# Resized: noface (566).jpg → 640x480
# Resized: noface (567).jpg → 640x480
# Resized: noface (568).jpg → 640x480
# Resized: noface (569).jpg → 640x480
# Resized: noface (57).jpg → 640x640
# Resized: noface (570).jpg → 480x640
# Resized: noface (571).jpg → 640x480
# Resized: noface (572).jpg → 640x480
# Resized: noface (573).jpg → 480x640
# Resized: noface (574).jpg → 640x480
# Resized: noface (575).jpg → 640x480
# Resized: noface (576).jpg → 640x480
# Resized: noface (577).jpg → 640x480
# Resized: noface (578).jpg → 640x480
# Resized: noface (579).jpg → 640x480
# Resized: noface (58).jpg → 640x640
# Resized: noface (580).jpg → 640x480
# Resized: noface (581).jpg → 640x480
# Resized: noface (582).jpg → 640x480
# Resized: noface (583).jpg → 640x480
# Resized: noface (584).jpg → 640x480
# Resized: noface (585).jpg → 640x480
# Resized: noface (586).jpg → 640x480
# Resized: noface (587).jpg → 640x480
# Resized: noface (588).jpg → 640x480
# Resized: noface (589).jpg → 640x480
# Resized: noface (59).jpg → 640x640
# Resized: noface (590).jpg → 640x480
# Resized: noface (591).jpg → 640x480
# Resized: noface (592).jpg → 640x480
# Resized: noface (593).jpg → 640x480
# Resized: noface (594).jpg → 640x480
# Resized: noface (595).jpg → 640x480
# Resized: noface (596).jpg → 640x480
# Resized: noface (597).jpg → 640x480
# Resized: noface (598).jpg → 640x480
# Resized: noface (599).jpg → 640x480
# Resized: noface (6).jpg → 640x640
# Resized: noface (60).jpg → 640x640
# Resized: noface (600).jpg → 640x480
# Resized: noface (601).jpg → 640x480
# Resized: noface (602).jpg → 640x480
# Resized: noface (603).jpg → 640x480
# Resized: noface (604).jpg → 640x480
# Resized: noface (605).jpg → 640x480
# Resized: noface (606).jpg → 640x480
# Resized: noface (607).jpg → 640x480
# Resized: noface (608).jpg → 640x480
# Resized: noface (609).jpg → 640x480
# Resized: noface (61).jpg → 640x358
# Resized: noface (610).jpg → 640x480
# Resized: noface (611).jpg → 640x480
# Resized: noface (612).jpg → 640x480
# Resized: noface (613).jpg → 640x480
# Resized: noface (614).jpg → 640x480
# Resized: noface (615).jpg → 640x480
# Resized: noface (616).jpg → 640x480
# Resized: noface (617).jpg → 640x480
# Resized: noface (618).jpg → 480x640
# Resized: noface (619).jpg → 480x640
# Resized: noface (62).jpg → 640x640
# Resized: noface (620).jpg → 640x480
# Resized: noface (621).jpg → 640x480
# Resized: noface (622).jpg → 640x480
# Resized: noface (623).jpg → 640x480
# Resized: noface (624).jpg → 640x480
# Resized: noface (625).jpg → 640x480
# Resized: noface (626).jpg → 640x480
# Resized: noface (627).jpg → 640x480
# Resized: noface (628).jpg → 640x480
# Resized: noface (629).jpg → 640x480
# Resized: noface (63).jpg → 425x640
# Resized: noface (630).jpg → 640x480
# Resized: noface (631).jpg → 640x480
# Resized: noface (632).jpg → 640x480
# Resized: noface (633).jpg → 640x480
# Resized: noface (634).jpg → 640x480
# Resized: noface (635).jpg → 640x480
# Resized: noface (636).jpg → 640x480
# Resized: noface (637).jpg → 640x480
# Resized: noface (638).jpg → 640x480
# Resized: noface (639).jpg → 640x480
# Resized: noface (64).jpg → 640x640
# Resized: noface (640).jpg → 640x480
# Resized: noface (641).jpg → 640x480
# Resized: noface (642).jpg → 640x480
# Resized: noface (643).jpg → 640x480
# Resized: noface (644).jpg → 640x480
# Resized: noface (645).jpg → 640x480
# Resized: noface (646).jpg → 640x480
# Resized: noface (647).jpg → 640x480
# Resized: noface (648).jpg → 640x480
# Resized: noface (649).jpg → 640x480
# Resized: noface (65).jpg → 640x640
# Resized: noface (650).jpg → 640x480
# Resized: noface (66).jpg → 640x640
# Resized: noface (67).jpg → 640x640
# Resized: noface (68).jpg → 640x640
# Resized: noface (69).jpg → 640x640
# Resized: noface (7).jpg → 640x640
# Resized: noface (70).jpg → 640x479
# Resized: noface (71).jpg → 640x640
# Resized: noface (72).jpg → 640x479
# Resized: noface (73).jpg → 640x640
# Resized: noface (74).jpg → 640x640
# Resized: noface (75).jpg → 640x640
# Resized: noface (76).jpg → 640x422
# Resized: noface (77).jpg → 640x640
# Resized: noface (78).jpg → 640x640
# Resized: noface (79).jpg → 640x640
# Resized: noface (8).jpg → 640x640
# Resized: noface (80).jpg → 640x479
# Resized: noface (81).jpg → 640x640
# Resized: noface (82).jpg → 640x398
# Resized: noface (83).jpg → 640x640
# Resized: noface (84).jpg → 640x640
# Resized: noface (85).jpg → 640x479
# Resized: noface (86).jpg → 640x640
# Resized: noface (87).jpg → 640x640
# Resized: noface (88).jpg → 640x640
# Resized: noface (89).jpg → 640x358
# Resized: noface (9).jpg → 640x640
# Resized: noface (90).jpg → 640x640
# Resized: noface (91).jpg → 640x536
# Resized: noface (92).jpg → 640x479
# Resized: noface (93).jpg → 424x640
# Resized: noface (94).jpg → 640x358
# Resized: noface (95).jpg → 640x640
# Resized: noface (96).jpg → 640x640
# Resized: noface (97).jpg → 640x640
# Resized: noface (98).jpg → 640x398
# Resized: noface (99).jpg → 640x640
